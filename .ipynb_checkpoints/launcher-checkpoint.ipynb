# %% [markdown]
# # This program summaries the versions of the Python librairies for a list of servers
#
# The servers list is :

# %%
servers = ['carex', 'latex', 'pyrex', 'silex', 'solex', 'vortex', 'sirex']

# %% [markdown]
# The following function get the versions of the librairies based on a servername :

# %%
import os, sys, fabric

def get_versions(servername):
    c = fabric.Connection(servername)
    uname = c.run('uname -s', hide=True)
    if 'Linux' in uname.stdout:
#         command = "python ~/Documents/versionScript.py"
        try:
            command = "pip freeze"
        except:
            print ("Error with the commande 'pip freeze'")
        return c.run(command, hide=True).stdout
    err = "No idea how to get disk space on {}!".format(uname)
    raise Exit(err)
# Out:
#   File "<ipython-input-8-52a734fc818a>", line 11
#     print "Error with the commande 'pip freeze'"
#                                                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
results = {}

for name in servers:
    print (name)
    result = get_versions(name)
    for lib in result.split("\n"):
        items = lib.split("==")
        if len(items) == 2:
            if items[0] not in results.keys():
                results[items[0]] = []
            results[items[0]].append([name, items[1]])
# Out:
# carex
# latex
# pyrex
# ---------------------------------------------------------------------------
# UnexpectedExit                            Traceback (most recent call last)
# <ipython-input-9-9ce168791e83> in <module>()
#       4 for name in servers:
#       5     print (name)
# ----> 6     result = get_versions(name)
#       7     for lib in result.split("\n"):
#       8         items = lib.split("==")
#
# <ipython-input-2-e9b0296610e7> in get_versions(servername)
#       7 #         command = "python ~/Documents/versionScript.py"
#       8         command = "pip freeze"
# ----> 9         return c.run(command, hide=True).stdout
#      10     err = "No idea how to get disk space on {}!".format(uname)
#      11     raise Exit(err)
#
# <decorator-gen-3> in run(self, command, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/fabric/connection.py in opens(method, self, *args, **kwargs)
#      28 def opens(method, self, *args, **kwargs):
#      29     self.open()
# ---> 30     return method(self, *args, **kwargs)
#      31
#      32
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/fabric/connection.py in run(self, command, **kwargs)
#     700         .. versionadded:: 2.0
#     701         """
# --> 702         return self._run(self._remote_runner(), command, **kwargs)
#     703
#     704     @opens
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/invoke/context.py in _run(self, runner, command, **kwargs)
#      99     def _run(self, runner, command, **kwargs):
#     100         command = self._prefix_commands(command)
# --> 101         return runner.run(command, **kwargs)
#     102
#     103     def sudo(self, command, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/invoke/runners.py in run(self, command, **kwargs)
#     269         """
#     270         try:
# --> 271             return self._run_body(command, **kwargs)
#     272         finally:
#     273             self.stop()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/invoke/runners.py in _run_body(self, command, **kwargs)
#     402             raise Failure(result, reason=watcher_errors[0])
#     403         if not (result or opts["warn"]):
# --> 404             raise UnexpectedExit(result)
#     405         return result
#     406
#
# UnexpectedExit: Encountered a bad command exit code!
#
# Command: 'pip freeze'
#
# Exit code: 127
#
# Stdout:
#
#
#
# Stderr:
#
# bash: pip: command not found

# %%
results = {}

for name in servers:
    try:
        result = get_versions(name)
        print (result)
    except:
        print ("Error with this server :", name)
# Out:
# 4Suite-XML==1.0.2
# antlr==2.7.5rc1
# appdirs==1.4.0
# arandr==0.1.9
# asn1crypto==0.23.0
# astroid==1.3.6
# attrs==17.2.0
# Automat==0.6.0
# Babel==2.4.0
# backports-abc==0.5
# backports.functools-lru-cache==1.5
# backports.weakref==1.0.post1
# Beaker==1.5.4
# BeautifulSoup==3.2.1
# beautifulsoup4==4.3.2
# biopython==1.68
# bkcharts==0.2
# bleach==1.5.0
# bokeh==0.12.6
# boto==2.48.0
# boto3==1.6.16
# botocore==1.9.16
# Bottleneck==0.6.0
# bz2file==0.98
# bzr==2.6.0
# CDDB==1.4
# certifi==2018.1.18
# cffi==1.11.2
# chardet==3.0.4
# compyte==0.0.1
# configobj==5.0.6
# constantly==15.1.0
# coverage==4.4.1
# cryptography==2.0.3
# cssselect==1.0.1
# cvxopt==1.1.8
# cycler==0.10.0
# Cython==0.27.1
# decorator==4.1.1
# defusedxml==0.5.0
# devscripts==1.0.0
# Django==1.8.15
# dockerfile-parse==0.0.5
# docutils==0.14
# dropbox==2.2.0
# duplicity==0.7.10
# ecdsa==0.11
# egenix-mx-base==3.2.8
# enum34==1.1.6
# fastcache==1.0.2
# fedpkg==1.25
# feedparser==5.2.0
# flickrapi==1.4.2
# fpconst==0.7.2
# funcsigs==1.0.2
# functools32==3.2.3.post2
# futures==3.2.0
# galternatives==0.9
# GDAL==2.0.2
# gdata==2.0.18
# gensim==2.2.0
# gitdb==0.6.4
# GitPython==1.0.1
# Glances==2.5.1
# gmpy2==2.0.7
# GnuPGInterface==0.3.2
# google-api-python-client==1.6.4
# googletrans==2.2.0
# gps==3.15
# graphviz==0.8.2
# gtg==0.3.1
# h5py==2.7.1
# html5lib==0.9999999
# httplib2==0.10.3
# hyperlink==17.3.1
# idna==2.5
# incremental==17.5.0
# iniparse==0.4
# ipaddress==1.0.18
# ipython==3.2.1
# ipython-genutils==0.2.0
# Jinja2==2.9.6
# jmespath==0.9.3
# jsonschema==2.6.0
# jupyter-core==4.3.0
# Keras==2.0.6
# kerberos==1.1
# keyring==10.4.0
# keyrings.alt==2.3
# kitchen==1.2.1
# langdetect==1.0.7
# Lasagne==0.1
# libasyncns==0.7
# liblarch==2.1.0
# lockfile==0.10.2
# logilab-common==0.63.2
# lxml==4.0.0
# M2Crypto==0.22.5
# Magic-file-extensions==0.2
# Mako==1.0.1
# Markdown==2.6.8
# MarkupSafe==1.0
# matplotlib==2.0.2
# meld==3.14.0
# mercurial==3.5.2
# mistune==0.6
# mock==2.0.0
# mpmath==1.0.0
# munch==2.0.2
# mutagen==1.29
# mysqlclient==1.3.7
# nbformat==4.3.0
# nbxmpp==0.5.3
# networkx==2.1
# nltk==3.2.5
# nose==1.3.7
# Numeric==24.2
# numexpr==2.4.6
# numpy==1.14.2
# oauth2client==4.1.2
# oauthlib==2.0.4
# opencv-contrib-python==3.2.0.8
# osbs-client==0.29
# packagedb-cli==2.13
# packaging==17.1
# pandas==0.20.3
# paramiko==1.15.2
# parsel==1.2.0
# Paste==1.7.5.1
# path.py==5.2
# pbr==3.1.1
# pdfshuffler==0.6.0
# pexpect==4.2.1
# Phatch==0.2.7
# Pillow==5.0.0
# pinyin==0.4.0
# plotly==2.0.12
# ply==3.6
# Pmw==2.0.1
# protobuf==3.3.0
# psutil==3.2.1
# psycopg2==2.6.1
# ptyprocess==0.5.2
# PuLP==1.6.8
# pwquality==1.3.0
# py==1.4.30
# pyasn1==0.3.6
# pyasn1-modules==0.1.4
# PyBrain==0.3
# PyChart==1.39
# pychecker==0.8.19
# pycparser==2.18
# pycrypto==2.6.1
# pycryptopp==0.6.0.1206569328141510525648634803928199668821045408958
# pycuda==2016.1.2
# pycurl==7.19.5.1
# pydot==1.2.3
# pyflakes==1.0.0
# pyglet==1.2.1
# Pygments==2.1.3
# pygobject==3.18.2
# pygpgme==0.3
# pygraphviz==1.3rc2
# pyliblzma==0.5.3
# pylint==1.4.3
# pyopencl==2015.2
# pyOpenSSL==17.3.0
# pyparsing==2.2.0
# pyparted==3.10.7
# pyPdf==1.13
# pypoppler==0.12.2
# Pyrex==0.9.9
# Pyro==3.16
# PySocks==1.5.6
# pytest==2.7.3
# python-bugzilla==1.2.2
# python-cloudfiles==1.7.11
# python-dateutil==2.6.1
# python-debian==0.1.31
# python-fedora==0.8.0
# python-gnupg==0.3.8
# python-ldap==2.4.17
# pytools==2015.1.2
# pytz==2018.3
# PyWavelets==0.5.2
# pyxattr==0.5.3
# pyxdg==0.25
# PyYAML==3.12
# pyzmq==14.7.0
# queuelib==1.4.2
# reportlab==3.3.0
# requests==2.18.1
# requests-oauthlib==0.8.0
# rope==0.10.2
# rpkg==1.46
# rpm-python==4.13.0rc1
# rsa==3.4.2
# rubber==1.4
# s3transfer==0.1.13
# scdate==1.10.9
# scikit-image==0.13.1
# scikit-learn==0.18.2
# scipy==1.0.1
# SciTools==0.9.0
# scsamba==1.2.100
# scsamba.dbus==1.2.100
# scservices==0.111.4
# scservices.dbus==0.111.4
# seaborn==0.8.1
# SecretStorage==2.3.1
# selenium==3.7.0
# service-identity==17.0.0
# simplegeneric==0.8.1
# simplejson==3.11.1
# SimPy==2.3.1
# singledispatch==3.4.0.3
# six==1.11.0
# sklearn==0.0
# slip==0.6.4
# slip.dbus==0.6.4
# slip.gtk==0.6.4
# smart-open==1.5.7
# smmap==0.9.0
# SOAPpy==0.12.22
# Sphinx==1.2.3
# spyder==2.3.8
# SSSDConfig==1.14.2
# subprocess32==3.2.7
# sympy==1.1.1
# tables==3.2.2
# Tempita==0.5.1
# tensorflow==1.2.1
# tensorflow-gpu==1.3.0
# tensorflow-tensorboard==0.1.7
# Theano==0.9.0
# tornado==4.5.1
# traitlets==4.3.2
# treetaggerwrapper==2.2.4
# tweepy==3.5.0
# TwitterSearch==1.0.1
# uniconvertor==2.0
# Unidecode==0.4.16
# uritemplate==3.0.0
# urlgrabber==3.10.1
# urllib3==1.21.1
# vboxapi==1.0
# virtualenv==12.0.7
# vobject==0.8.1rc0
# w3lib==1.18.0
# webencodings==0.5.1
# Werkzeug==0.12.2
# wstools==0.4.5
# wxPython==3.0.2.0
# wxPython-common==3.0.2.0
# xlrd==0.9.2
# xlwt==0.7.4
# xvfbwrapper==0.2.9
# yum-metadata-parser==1.1.4
# zenmap==7.12
# zope.interface==4.4.3
#
# 4Suite-XML==1.0.2
# Automat==0.6.0
# Babel==2.5.3
# Beaker==1.5.4
# BeautifulSoup==3.2.1
# Cython==0.27.1
# DecoratorTools==1.8
# Django==1.5.4
# GDAL==1.9.2
# GitPython==0.3.2rc1
# Glances==1.7.1
# GnuPGInterface==0.3.2
# IPy==0.75
# Jinja2==2.10
# Keras==2.0.8
# Lasagne==0.2.dev1
# M2Crypto==0.21.1
# Magic-file-extensions==0.2
# Mako==0.7.3
# Markdown==2.6.9
# MarkupSafe==1.0
# MySQL-python==1.2.3
# Numeric==24.2
# Paste==1.7.5.1
# Pillow==5.0.0
# Pmw==2.0.1
# PuLP==1.6.8
# PyBrain==0.3
# PyChart==1.39
# PyWavelets==0.5.2
# PyYAML==3.12
# Pygments==1.4
# Pyrex==0.9.9
# Pyro==3.16
# SOAPpy==0.12.22
# SSSDConfig==1.11.2
# SciTools==0.9.0
# ScientificPython==2.8
# SecretStorage==2.3.1
# SimPy==2.3.1
# Sphinx==1.1.3
# Tempita==0.5.1
# Theano==1.0.1
# TwitterSearch==1.0.1
# Werkzeug==0.12.2
# ZSI==2.1a1
# asn1crypto==0.24.0
# astroid==1.0.0
# async==0.6.1
# attrs==17.4.0
# backports-abc==0.5
# backports.functools-lru-cache==1.5
# backports.ssl-match-hostname==3.4.0.2
# backports.weakref==1.0.post1
# beautifulsoup4==4.6.0
# biopython==1.60
# bkcharts==0.2
# bleach==2.1.3
# blivet==0.17
# bokeh==0.12.15
# boto==2.48.0
# boto3==1.7.0
# botocore==1.10.0
# bunch==1.0.1
# bz2file==0.98
# bzr==2.5.1
# certifi==2018.1.18
# cffi==1.11.5
# chardet==3.0.4
# configobj==5.0.6
# constantly==15.1.0
# coverage==4.4.1
# cryptography==2.1.1
# cssselect==1.0.1
# cupshelpers==1.0
# cvxopt==1.1.6
# cycler==0.10.0
# decorator==4.2.1
# defusedxml==0.5.0
# devscripts==1.0.0
# di==0.3
# distribute==0.6.36
# docutils==0.14
# duplicity==0.6.21
# egenix-mx-base==3.2.5
# enum34==1.1.6
# fedpkg==1.14
# feedparser==5.1.3
# flickrapi==1.4.2
# fontforge==1.0
# fpconst==0.7.2
# fros==1.0
# funcsigs==1.0.2
# functools32==3.2.3.post2
# futures==3.2.0
# galternatives==0.9
# gdata==2.0.17
# gensim==3.4.0
# gitdb==0.5.4
# gnuplot-py==1.8
# google-api-python-client==1.6.4
# googletrans==2.2.0
# gps==3.9
# graphviz==0.8.2
# gtg==0.3
# h5py==2.7.1
# html5lib==1.0.1
# httplib2==0.10.3
# hyperlink==17.3.1
# idna==2.6
# incremental==17.5.0
# iniparse==0.4
# initial-setup==0.3.6
# ipaddress==1.0.18
# ipython==0.13.2
# ipython-genutils==0.2.0
# jmespath==0.9.3
# jsonschema==2.6.0
# jupyter-core==4.3.0
# kerberos==1.1
# keyring==10.4.0
# keyrings.alt==2.3
# kitchen==1.1.1
# langdetect==1.0.7
# langtable==0.0.13
# libasyncns==0.7
# liblarch==2.1.0
# lockfile==0.9.1
# logilab-common==0.60.0
# lxml==4.1.1
# matplotlib==2.1.2
# mercurial==2.6.3
# mglob==0.4
# mock==2.0.0
# mpmath==1.0.0
# mutagen==1.20
# nbformat==4.4.0
# networkx==2.1
# nltk==3.2.5
# nose==1.3.0
# numexpr==2.0.1
# numpy==1.14.3
# oauth2client==4.1.2
# oauthlib==2.0.4
# offtrac==0.0.4
# opencv-contrib-python==3.3.0.10
# packaging==17.1
# pandas==0.20.3
# paramiko==1.10.1
# parsel==1.2.0
# pbr==3.1.1
# pdfshuffler==0.6.0
# pexpect==4.2.1
# pexpect-u==2.5.1
# pinyin==0.4.0
# plotly==2.1.0
# protobuf==3.4.0
# psutil==0.6.1
# psycopg2==2.4.5
# ptyprocess==0.5.2
# pyOpenSSL==17.3.0
# pyPdf==1.13
# pyasn1==0.3.7
# pyasn1-modules==0.1.5
# pychecker==0.8.19
# pycparser==2.18
# pycrypto==2.6.1
# pycryptopp==0.6.0.1206569328141510525648634803928199668821045408958
# pycups==1.9.63
# pycurl==7.19.0
# pydot==1.2.3
# pyflakes==0.7.2
# pyglet==1.2a1
# pygobject==3.8.3
# pygpgme==0.3
# pyinotify==0.9.4
# pykickstart==1.99.32
# pyliblzma==0.5.3
# pylint==1.0.0
# pymol==1.6.0.0
# pyparsing==2.2.0
# pyparted==3.9
# python-bugzilla==0.9.0
# python-cloudfiles==1.7.10
# python-dateutil==2.7.2
# python-debian==0.1.31
# python-fedora==0.3.32.3
# python-ldap==2.4.6
# python-meh==0.25
# python-nss==0.14.0
# pytz==2018.3
# pyxattr==0.5.1
# pyxdg==0.25
# pyzmq==13.0.0
# queuelib==1.4.2
# reportlab==2.5
# requests==2.18.4
# requests-oauthlib==0.8.0
# rope==0.9.4
# rpkg==1.18
# rsa==3.4.2
# rubber==1.1
# s3transfer==0.1.13
# scdate==1.10.6
# scikit-image==0.13.1
# scikit-learn==0.19.0
# scipy==1.1.0
# scsamba==1.2.100
# scsamba.dbus==1.2.100
# scservices==0.101.10
# scservices.dbus==0.101.10
# seaborn==0.8.1
# selenium==3.7.0
# service-identity==17.0.0
# simplegeneric==0.8.1
# simplejson==3.11.1
# singledispatch==3.4.0.3
# six==1.11.0
# sklearn==0.0
# slip==0.4.0
# slip.dbus==0.4.0
# slip.gtk==0.4.0
# smart-open==1.5.7
# smmap==0.8.1
# spambayes==1.1a6
# spyder==2.2.4
# subprocess32==3.2.7
# sympy==1.1.1
# tables==2.4.0
# tensorflow==1.3.0
# tensorflow-gpu==1.3.0
# tensorflow-tensorboard==0.1.8
# tornado==5.0.1
# traitlets==4.3.2
# treetaggerwrapper==2.2.4
# tweepy==3.5.0
# uniconvertor==2.0
# uritemplate==3.0.0
# urlgrabber==3.10
# urllib3==1.22
# vboxapi==1.0
# virtualenv==1.10.1
# vobject==0.8.1rc0
# w3lib==1.18.0
# webencodings==0.5.1
# wheel==0.30.0
# wsgiref==0.1.2
# wstools==0.4.5
# wxPython==2.8.12.0
# wxPython-common==2.8.12.0
# xvfbwrapper==0.2.9
# yum-langpacks==0.4.1
# yum-metadata-parser==1.1.4
# zenmap==6.40
# zope.interface==4.4.3
# Error with this server : pyrex
# asn1crypto==0.24.0
# attrs==17.4.0
# Automat==0.6.0
# Babel==2.5.3
# backports-abc==0.5
# backports.functools-lru-cache==1.5
# backports.weakref==1.0.post1
# BeautifulSoup==3.2.1
# beautifulsoup4==4.6.0
# bkcharts==0.2
# bleach==2.1.3
# bokeh==0.12.15
# boto==2.48.0
# boto3==1.7.0
# botocore==1.10.0
# bz2file==0.98
# certifi==2018.1.18
# cffi==1.11.5
# chardet==3.0.4
# configobj==5.0.6
# constantly==15.1.0
# coverage==4.4.1
# cryptography==2.1.1
# cssselect==1.0.1
# cycler==0.10.0
# Cython==0.27.1
# decorator==4.2.1
# defusedxml==0.5.0
# devscripts==1.0.0
# docutils==0.14
# enum34==1.1.6
# fpconst==0.7.2
# funcsigs==1.0.2
# functools32==3.2.3.post2
# futures==3.2.0
# gensim==3.4.0
# gnuplot-py==1.8
# google-api-python-client==1.6.4
# googletrans==2.2.0
# graphviz==0.8.2
# h5py==2.7.1
# html5lib==1.0.1
# httplib2==0.10.3
# hyperlink==17.3.1
# idna==2.6
# incremental==17.5.0
# ipaddress==1.0.18
# ipython==2.3.0
# ipython-genutils==0.2.0
# Jinja2==2.10
# jmespath==0.9.3
# jsonschema==2.6.0
# jupyter-core==4.3.0
# Keras==2.0.8
# keyring==10.4.0
# keyrings.alt==2.3
# langdetect==1.0.7
# Lasagne==0.2.dev1
# lxml==4.1.1
# Magic-file-extensions==0.2
# Markdown==2.6.9
# MarkupSafe==1.0
# matplotlib==2.1.2
# mock==2.0.0
# mpmath==1.0.0
# nbformat==4.4.0
# networkx==2.1
# nltk==3.2.5
# numpy==1.14.3
# oauth2client==4.1.2
# oauthlib==2.0.4
# opencv-contrib-python==3.3.0.10
# packaging==17.1
# pandas==0.20.3
# parsel==1.2.0
# pbr==3.1.1
# pexpect==4.2.1
# PIL==1.1.7
# Pillow==5.0.0
# pinyin==0.4.0
# plotly==2.1.0
# Pmw==2.0.1
# protobuf==3.4.0
# ptyprocess==0.5.2
# PuLP==1.6.8
# pyasn1==0.3.7
# pyasn1-modules==0.1.5
# PyBrain==0.3
# pycparser==2.18
# pycrypto==2.6.1
# pydot==1.2.3
# pygobject==3.14.0
# pyOpenSSL==17.3.0
# pyparsing==2.2.0
# Pyro==3.16
# python-apt==0.9.3.10
# python-dateutil==2.7.2
# python-debian==0.1.31
# python-debianbts==1.11
# pytz==2018.3
# PyWavelets==0.5.2
# PyX==0.12.1
# pyxdg==0.25
# PyYAML==3.12
# queuelib==1.4.2
# reportbug==6.5.1
# requests==2.18.4
# requests-oauthlib==0.8.0
# rsa==3.4.2
# s3transfer==0.1.13
# ScientificPython==2.9.4
# scikit-image==0.13.1
# scikit-learn==0.19.0
# scipy==1.1.0
# SciTools==0.9.0
# seaborn==0.8.1
# SecretStorage==2.3.1
# selenium==3.7.0
# service-identity==17.0.0
# simplegeneric==0.8.1
# simplejson==3.11.1
# singledispatch==3.4.0.3
# six==1.11.0
# sklearn==0.0
# smart-open==1.5.7
# SOAPpy==0.12.22
# subprocess32==3.2.7
# sympy==1.1.1
# tensorflow==1.3.0
# tensorflow-gpu==1.3.0
# tensorflow-tensorboard==0.1.8
# Theano==1.0.1
# tornado==5.0.1
# traitlets==4.3.2
# treetaggerwrapper==2.2.4
# tweepy==3.5.0
# TwitterSearch==1.0.1
# uritemplate==3.0.0
# urllib3==1.22
# VTK==5.8.0
# w3lib==1.18.0
# webencodings==0.5.1
# Werkzeug==0.12.2
# wstools==0.4.5
# xvfbwrapper==0.2.9
# zope.interface==4.4.3
#
# Error with this server : solex
# 4Suite-XML==1.0.2
# antlr==2.7.5rc1
# arandr==0.1.9
# asn1crypto==0.23.0
# astroid==1.3.6
# attrs==17.2.0
# Automat==0.6.0
# Babel==2.4.0
# backports-abc==0.5
# backports.functools-lru-cache==1.5
# backports.weakref==1.0.post1
# Beaker==1.5.4
# BeautifulSoup==3.2.1
# beautifulsoup4==4.3.2
# biopython==1.68
# bkcharts==0.2
# bleach==1.5.0
# bokeh==0.12.6
# boto==2.48.0
# boto3==1.6.16
# botocore==1.9.16
# Bottleneck==0.6.0
# bz2file==0.98
# bzr==2.6.0
# CDDB==1.4
# certifi==2018.1.18
# cffi==1.11.2
# chardet==3.0.4
# configobj==5.0.6
# constantly==15.1.0
# coverage==4.4.1
# cryptography==2.0.3
# cssselect==1.0.1
# cvxopt==1.1.8
# cycler==0.10.0
# Cython==0.27.1
# decorator==4.1.1
# defusedxml==0.5.0
# devscripts==1.0.0
# Django==1.8.15
# dockerfile-parse==0.0.5
# docutils==0.14
# dropbox==2.2.0
# duplicity==0.7.10
# ecdsa==0.11
# egenix-mx-base==3.2.8
# enum34==1.1.6
# fastcache==1.0.2
# fedpkg==1.25
# feedparser==5.2.0
# flickrapi==1.4.2
# fpconst==0.7.2
# funcsigs==1.0.2
# functools32==3.2.3.post2
# futures==3.2.0
# galternatives==0.9
# GDAL==2.0.2
# gdata==2.0.18
# gensim==2.2.0
# gitdb==0.6.4
# GitPython==1.0.1
# Glances==2.5.1
# gmpy2==2.0.7
# GnuPGInterface==0.3.2
# google-api-python-client==1.6.4
# googletrans==2.2.0
# gps==3.15
# graphviz==0.8.2
# gtg==0.3.1
# h5py==2.7.1
# html5lib==0.9999999
# httplib2==0.10.3
# hyperlink==17.3.1
# idna==2.5
# incremental==17.5.0
# iniparse==0.4
# ipaddress==1.0.18
# ipython==3.2.1
# ipython-genutils==0.2.0
# Jinja2==2.9.6
# jmespath==0.9.3
# jsonschema==2.6.0
# jupyter-core==4.3.0
# Keras==2.0.6
# kerberos==1.1
# keyring==10.4.0
# keyrings.alt==2.3
# kitchen==1.2.1
# langdetect==1.0.7
# Lasagne==0.1
# libasyncns==0.7
# liblarch==2.1.0
# lockfile==0.10.2
# logilab-common==0.63.2
# lxml==4.0.0
# M2Crypto==0.22.5
# Magic-file-extensions==0.2
# Mako==1.0.1
# Markdown==2.6.8
# MarkupSafe==1.0
# matplotlib==2.0.2
# meld==3.14.0
# mercurial==3.5.2
# mistune==0.6
# mock==2.0.0
# mpmath==1.0.0
# munch==2.0.2
# mutagen==1.29
# mysqlclient==1.3.7
# nbformat==4.3.0
# nbxmpp==0.5.3
# networkx==2.1
# nltk==3.2.5
# nose==1.3.7
# Numeric==24.2
# numexpr==2.4.6
# numpy==1.14.2
# oauth2client==4.1.2
# oauthlib==2.0.4
# opencv-contrib-python==3.2.0.8
# osbs-client==0.29
# packagedb-cli==2.13
# packaging==17.1
# pandas==0.20.3
# paramiko==1.15.2
# parsel==1.2.0
# Paste==1.7.5.1
# path.py==5.2
# pbr==3.1.1
# pdfshuffler==0.6.0
# pexpect==4.2.1
# Phatch==0.2.7
# Pillow==5.0.0
# pinyin==0.4.0
# plotly==2.0.12
# ply==3.6
# Pmw==2.0.1
# protobuf==3.3.0
# psutil==3.2.1
# psycopg2==2.6.1
# ptyprocess==0.5.2
# PuLP==1.6.8
# pwquality==1.3.0
# pyasn1==0.3.6
# pyasn1-modules==0.1.4
# PyBrain==0.3
# PyChart==1.39
# pychecker==0.8.19
# pycparser==2.18
# pycrypto==2.6.1
# pycryptopp==0.6.0.1206569328141510525648634803928199668821045408958
# pycurl==7.19.5.1
# pydot==1.2.3
# pyflakes==1.0.0
# pyglet==1.2.1
# Pygments==2.1.3
# pygobject==3.18.2
# pygpgme==0.3
# pygraphviz==1.3rc2
# pyliblzma==0.5.3
# pylint==1.4.3
# pyOpenSSL==17.3.0
# pyparsing==2.2.0
# pyparted==3.10.7
# pyPdf==1.13
# pypoppler==0.12.2
# Pyrex==0.9.9
# Pyro==3.16
# PySocks==1.5.6
# python-bugzilla==1.2.2
# python-cloudfiles==1.7.11
# python-dateutil==2.6.1
# python-debian==0.1.31
# python-fedora==0.8.0
# python-gflags==2.0
# python-gnupg==0.3.8
# python-ldap==2.4.17
# pytz==2018.3
# PyWavelets==0.5.2
# pyxattr==0.5.3
# pyxdg==0.25
# PyYAML==3.12
# pyzmq==14.7.0
# queuelib==1.4.2
# reportlab==3.3.0
# requests==2.18.1
# requests-oauthlib==0.8.0
# rope==0.10.2
# rpkg==1.46
# rpm-python==4.13.0rc1
# rsa==3.4.2
# rubber==1.4
# s3transfer==0.1.13
# scdate==1.10.9
# scikit-image==0.13.1
# scikit-learn==0.18.2
# scipy==1.0.1
# SciTools==0.9.0
# scsamba==1.2.100
# scsamba.dbus==1.2.100
# scservices==0.111.4
# scservices.dbus==0.111.4
# seaborn==0.8.1
# SecretStorage==2.3.1
# selenium==3.7.0
# service-identity==17.0.0
# simplegeneric==0.8.1
# simplejson==3.11.1
# SimPy==2.3.1
# singledispatch==3.4.0.3
# six==1.11.0
# sklearn==0.0
# slip==0.6.4
# slip.dbus==0.6.4
# slip.gtk==0.6.4
# smart-open==1.5.7
# smmap==0.9.0
# SOAPpy==0.12.22
# Sphinx==1.2.3
# spyder==2.3.8
# SSSDConfig==1.14.2
# subprocess32==3.2.7
# sympy==1.1.1
# tables==3.2.2
# Tempita==0.5.1
# tensorflow==1.2.1
# tensorflow-gpu==1.3.0
# tensorflow-tensorboard==0.1.7
# Theano==0.9.0
# tornado==4.5.1
# traitlets==4.3.2
# treetaggerwrapper==2.2.4
# tweepy==3.5.0
# TwitterSearch==1.0.1
# uniconvertor==2.0
# Unidecode==0.4.16
# uritemplate==3.0.0
# urlgrabber==3.10.1
# urllib3==1.21.1
# virtualenv==12.0.7
# vobject==0.8.1rc0
# w3lib==1.18.0
# webencodings==0.5.1
# Werkzeug==0.12.2
# wheel==0.30.0
# wstools==0.4.5
# wxPython==3.0.2.0
# wxPython-common==3.0.2.0
# xlrd==0.9.2
# xlwt==0.7.4
# xvfbwrapper==0.2.9
# yum-metadata-parser==1.1.4
# zenmap==7.12
# zope.interface==4.4.3
#
# Error with this server : sirex

# %%
for x in results:    print (x, "\t", results[x])
# Out:
# decorator 	 [['carex', '4.1.1'], ['latex', '4.2.1'], ['silex', '4.2.1'], ['vortex', '4.1.1']]
# googletrans 	 [['carex', '2.2.0'], ['latex', '2.2.0'], ['silex', '2.2.0'], ['vortex', '2.2.0']]
# tables 	 [['carex', '3.2.2'], ['latex', '2.4.0'], ['vortex', '3.2.2']]
# pyxdg 	 [['carex', '0.25'], ['latex', '0.25'], ['silex', '0.25'], ['vortex', '0.25']]
# scikit-learn 	 [['carex', '0.18.2'], ['latex', '0.19.0'], ['silex', '0.19.0'], ['vortex', '0.18.2']]
# pwquality 	 [['carex', '1.3.0'], ['vortex', '1.3.0']]
# SecretStorage 	 [['carex', '2.3.1'], ['latex', '2.3.1'], ['silex', '2.3.1'], ['vortex', '2.3.1']]
# singledispatch 	 [['carex', '3.4.0.3'], ['latex', '3.4.0.3'], ['silex', '3.4.0.3'], ['vortex', '3.4.0.3']]
# zenmap 	 [['carex', '7.12'], ['latex', '6.40'], ['vortex', '7.12']]
# reportlab 	 [['carex', '3.3.0'], ['latex', '2.5'], ['vortex', '3.3.0']]
# PyBrain 	 [['carex', '0.3'], ['latex', '0.3'], ['silex', '0.3'], ['vortex', '0.3']]
# enum34 	 [['carex', '1.1.6'], ['latex', '1.1.6'], ['silex', '1.1.6'], ['vortex', '1.1.6']]
# ipaddress 	 [['carex', '1.0.18'], ['latex', '1.0.18'], ['silex', '1.0.18'], ['vortex', '1.0.18']]
# MySQL-python 	 [['latex', '1.2.3']]
# SOAPpy 	 [['carex', '0.12.22'], ['latex', '0.12.22'], ['silex', '0.12.22'], ['vortex', '0.12.22']]
# cssselect 	 [['carex', '1.0.1'], ['latex', '1.0.1'], ['silex', '1.0.1'], ['vortex', '1.0.1']]
# pyOpenSSL 	 [['carex', '17.3.0'], ['latex', '17.3.0'], ['silex', '17.3.0'], ['vortex', '17.3.0']]
# devscripts 	 [['carex', '1.0.0'], ['latex', '1.0.0'], ['silex', '1.0.0'], ['vortex', '1.0.0']]
# h5py 	 [['carex', '2.7.1'], ['latex', '2.7.1'], ['silex', '2.7.1'], ['vortex', '2.7.1']]
# scdate 	 [['carex', '1.10.9'], ['latex', '1.10.6'], ['vortex', '1.10.9']]
# antlr 	 [['carex', '2.7.5rc1'], ['vortex', '2.7.5rc1']]
# nose 	 [['carex', '1.3.7'], ['latex', '1.3.0'], ['vortex', '1.3.7']]
# scservices.dbus 	 [['carex', '0.111.4'], ['latex', '0.101.10'], ['vortex', '0.111.4']]
# Keras 	 [['carex', '2.0.6'], ['latex', '2.0.8'], ['silex', '2.0.8'], ['vortex', '2.0.6']]
# jsonschema 	 [['carex', '2.6.0'], ['latex', '2.6.0'], ['silex', '2.6.0'], ['vortex', '2.6.0']]
# uritemplate 	 [['carex', '3.0.0'], ['latex', '3.0.0'], ['silex', '3.0.0'], ['vortex', '3.0.0']]
# pyasn1-modules 	 [['carex', '0.1.4'], ['latex', '0.1.5'], ['silex', '0.1.5'], ['vortex', '0.1.4']]
# iniparse 	 [['carex', '0.4'], ['latex', '0.4'], ['vortex', '0.4']]
# Werkzeug 	 [['carex', '0.12.2'], ['latex', '0.12.2'], ['silex', '0.12.2'], ['vortex', '0.12.2']]
# protobuf 	 [['carex', '3.3.0'], ['latex', '3.4.0'], ['silex', '3.4.0'], ['vortex', '3.3.0']]
# mysqlclient 	 [['carex', '1.3.7'], ['vortex', '1.3.7']]
# BeautifulSoup 	 [['carex', '3.2.1'], ['latex', '3.2.1'], ['silex', '3.2.1'], ['vortex', '3.2.1']]
# mock 	 [['carex', '2.0.0'], ['latex', '2.0.0'], ['silex', '2.0.0'], ['vortex', '2.0.0']]
# appdirs 	 [['carex', '1.4.0']]
# gensim 	 [['carex', '2.2.0'], ['latex', '3.4.0'], ['silex', '3.4.0'], ['vortex', '2.2.0']]
# urllib3 	 [['carex', '1.21.1'], ['latex', '1.22'], ['silex', '1.22'], ['vortex', '1.21.1']]
# pycups 	 [['latex', '1.9.63']]
# simplegeneric 	 [['carex', '0.8.1'], ['latex', '0.8.1'], ['silex', '0.8.1'], ['vortex', '0.8.1']]
# tensorflow 	 [['carex', '1.2.1'], ['latex', '1.3.0'], ['silex', '1.3.0'], ['vortex', '1.2.1']]
# boto3 	 [['carex', '1.6.16'], ['latex', '1.7.0'], ['silex', '1.7.0'], ['vortex', '1.6.16']]
# numpy 	 [['carex', '1.14.2'], ['latex', '1.14.3'], ['silex', '1.14.3'], ['vortex', '1.14.2']]
# seaborn 	 [['carex', '0.8.1'], ['latex', '0.8.1'], ['silex', '0.8.1'], ['vortex', '0.8.1']]
# ipython-genutils 	 [['carex', '0.2.0'], ['latex', '0.2.0'], ['silex', '0.2.0'], ['vortex', '0.2.0']]
# selenium 	 [['carex', '3.7.0'], ['latex', '3.7.0'], ['silex', '3.7.0'], ['vortex', '3.7.0']]
# funcsigs 	 [['carex', '1.0.2'], ['latex', '1.0.2'], ['silex', '1.0.2'], ['vortex', '1.0.2']]
# spyder 	 [['carex', '2.3.8'], ['latex', '2.2.4'], ['vortex', '2.3.8']]
# pytest 	 [['carex', '2.7.3']]
# defusedxml 	 [['carex', '0.5.0'], ['latex', '0.5.0'], ['silex', '0.5.0'], ['vortex', '0.5.0']]
# python-nss 	 [['latex', '0.14.0']]
# wheel 	 [['latex', '0.30.0'], ['vortex', '0.30.0']]
# fontforge 	 [['latex', '1.0']]
# tensorflow-gpu 	 [['carex', '1.3.0'], ['latex', '1.3.0'], ['silex', '1.3.0'], ['vortex', '1.3.0']]
# pygobject 	 [['carex', '3.18.2'], ['latex', '3.8.3'], ['silex', '3.14.0'], ['vortex', '3.18.2']]
# Babel 	 [['carex', '2.4.0'], ['latex', '2.5.3'], ['silex', '2.5.3'], ['vortex', '2.4.0']]
# PySocks 	 [['carex', '1.5.6'], ['vortex', '1.5.6']]
# pygpgme 	 [['carex', '0.3'], ['latex', '0.3'], ['vortex', '0.3']]
# functools32 	 [['carex', '3.2.3.post2'], ['latex', '3.2.3.post2'], ['silex', '3.2.3.post2'], ['vortex', '3.2.3.post2']]
# packagedb-cli 	 [['carex', '2.13'], ['vortex', '2.13']]
# idna 	 [['carex', '2.5'], ['latex', '2.6'], ['silex', '2.6'], ['vortex', '2.5']]
# traitlets 	 [['carex', '4.3.2'], ['latex', '4.3.2'], ['silex', '4.3.2'], ['vortex', '4.3.2']]
# VTK 	 [['silex', '5.8.0']]
# tensorflow-tensorboard 	 [['carex', '0.1.7'], ['latex', '0.1.8'], ['silex', '0.1.8'], ['vortex', '0.1.7']]
# pyinotify 	 [['latex', '0.9.4']]
# Numeric 	 [['carex', '24.2'], ['latex', '24.2'], ['vortex', '24.2']]
# PyChart 	 [['carex', '1.39'], ['latex', '1.39'], ['vortex', '1.39']]
# oauthlib 	 [['carex', '2.0.4'], ['latex', '2.0.4'], ['silex', '2.0.4'], ['vortex', '2.0.4']]
# pyxattr 	 [['carex', '0.5.3'], ['latex', '0.5.1'], ['vortex', '0.5.3']]
# smmap 	 [['carex', '0.9.0'], ['latex', '0.8.1'], ['vortex', '0.9.0']]
# asn1crypto 	 [['carex', '0.23.0'], ['latex', '0.24.0'], ['silex', '0.24.0'], ['vortex', '0.23.0']]
# rope 	 [['carex', '0.10.2'], ['latex', '0.9.4'], ['vortex', '0.10.2']]
# gdata 	 [['carex', '2.0.18'], ['latex', '2.0.17'], ['vortex', '2.0.18']]
# pinyin 	 [['carex', '0.4.0'], ['latex', '0.4.0'], ['silex', '0.4.0'], ['vortex', '0.4.0']]
# pdfshuffler 	 [['carex', '0.6.0'], ['latex', '0.6.0'], ['vortex', '0.6.0']]
# python-meh 	 [['latex', '0.25']]
# PIL 	 [['silex', '1.1.7']]
# Glances 	 [['carex', '2.5.1'], ['latex', '1.7.1'], ['vortex', '2.5.1']]
# lockfile 	 [['carex', '0.10.2'], ['latex', '0.9.1'], ['vortex', '0.10.2']]
# nbformat 	 [['carex', '4.3.0'], ['latex', '4.4.0'], ['silex', '4.4.0'], ['vortex', '4.3.0']]
# gitdb 	 [['carex', '0.6.4'], ['latex', '0.5.4'], ['vortex', '0.6.4']]
# cryptography 	 [['carex', '2.0.3'], ['latex', '2.1.1'], ['silex', '2.1.1'], ['vortex', '2.0.3']]
# tweepy 	 [['carex', '3.5.0'], ['latex', '3.5.0'], ['silex', '3.5.0'], ['vortex', '3.5.0']]
# cycler 	 [['carex', '0.10.0'], ['latex', '0.10.0'], ['silex', '0.10.0'], ['vortex', '0.10.0']]
# bzr 	 [['carex', '2.6.0'], ['latex', '2.5.1'], ['vortex', '2.6.0']]
# ptyprocess 	 [['carex', '0.5.2'], ['latex', '0.5.2'], ['silex', '0.5.2'], ['vortex', '0.5.2']]
# GnuPGInterface 	 [['carex', '0.3.2'], ['latex', '0.3.2'], ['vortex', '0.3.2']]
# reportbug 	 [['silex', '6.5.1']]
# pyflakes 	 [['carex', '1.0.0'], ['latex', '0.7.2'], ['vortex', '1.0.0']]
# Theano 	 [['carex', '0.9.0'], ['latex', '1.0.1'], ['silex', '1.0.1'], ['vortex', '0.9.0']]
# sklearn 	 [['carex', '0.0'], ['latex', '0.0'], ['silex', '0.0'], ['vortex', '0.0']]
# Magic-file-extensions 	 [['carex', '0.2'], ['latex', '0.2'], ['silex', '0.2'], ['vortex', '0.2']]
# duplicity 	 [['carex', '0.7.10'], ['latex', '0.6.21'], ['vortex', '0.7.10']]
# ScientificPython 	 [['latex', '2.8'], ['silex', '2.9.4']]
# dockerfile-parse 	 [['carex', '0.0.5'], ['vortex', '0.0.5']]
# opencv-contrib-python 	 [['carex', '3.2.0.8'], ['latex', '3.3.0.10'], ['silex', '3.3.0.10'], ['vortex', '3.2.0.8']]
# DecoratorTools 	 [['latex', '1.8']]
# gtg 	 [['carex', '0.3.1'], ['latex', '0.3'], ['vortex', '0.3.1']]
# parsel 	 [['carex', '1.2.0'], ['latex', '1.2.0'], ['silex', '1.2.0'], ['vortex', '1.2.0']]
# rsa 	 [['carex', '3.4.2'], ['latex', '3.4.2'], ['silex', '3.4.2'], ['vortex', '3.4.2']]
# MarkupSafe 	 [['carex', '1.0'], ['latex', '1.0'], ['silex', '1.0'], ['vortex', '1.0']]
# python-gflags 	 [['vortex', '2.0']]
# pylint 	 [['carex', '1.4.3'], ['latex', '1.0.0'], ['vortex', '1.4.3']]
# ipython 	 [['carex', '3.2.1'], ['latex', '0.13.2'], ['silex', '2.3.0'], ['vortex', '3.2.1']]
# numexpr 	 [['carex', '2.4.6'], ['latex', '2.0.1'], ['vortex', '2.4.6']]
# pychecker 	 [['carex', '0.8.19'], ['latex', '0.8.19'], ['vortex', '0.8.19']]
# python-debian 	 [['carex', '0.1.31'], ['latex', '0.1.31'], ['silex', '0.1.31'], ['vortex', '0.1.31']]
# pyasn1 	 [['carex', '0.3.6'], ['latex', '0.3.7'], ['silex', '0.3.7'], ['vortex', '0.3.6']]
# python-cloudfiles 	 [['carex', '1.7.11'], ['latex', '1.7.10'], ['vortex', '1.7.11']]
# networkx 	 [['carex', '2.1'], ['latex', '2.1'], ['silex', '2.1'], ['vortex', '2.1']]
# packaging 	 [['carex', '17.1'], ['latex', '17.1'], ['silex', '17.1'], ['vortex', '17.1']]
# pbr 	 [['carex', '3.1.1'], ['latex', '3.1.1'], ['silex', '3.1.1'], ['vortex', '3.1.1']]
# html5lib 	 [['carex', '0.9999999'], ['latex', '1.0.1'], ['silex', '1.0.1'], ['vortex', '0.9999999']]
# gps 	 [['carex', '3.15'], ['latex', '3.9'], ['vortex', '3.15']]
# pexpect 	 [['carex', '4.2.1'], ['latex', '4.2.1'], ['silex', '4.2.1'], ['vortex', '4.2.1']]
# dropbox 	 [['carex', '2.2.0'], ['vortex', '2.2.0']]
# yum-metadata-parser 	 [['carex', '1.1.4'], ['latex', '1.1.4'], ['vortex', '1.1.4']]
# python-fedora 	 [['carex', '0.8.0'], ['latex', '0.3.32.3'], ['vortex', '0.8.0']]
# uniconvertor 	 [['carex', '2.0'], ['latex', '2.0'], ['vortex', '2.0']]
# path.py 	 [['carex', '5.2'], ['vortex', '5.2']]
# docutils 	 [['carex', '0.14'], ['latex', '0.14'], ['silex', '0.14'], ['vortex', '0.14']]
# bokeh 	 [['carex', '0.12.6'], ['latex', '0.12.15'], ['silex', '0.12.15'], ['vortex', '0.12.6']]
# virtualenv 	 [['carex', '12.0.7'], ['latex', '1.10.1'], ['vortex', '12.0.7']]
# pyopencl 	 [['carex', '2015.2']]
# GitPython 	 [['carex', '1.0.1'], ['latex', '0.3.2rc1'], ['vortex', '1.0.1']]
# pytz 	 [['carex', '2018.3'], ['latex', '2018.3'], ['silex', '2018.3'], ['vortex', '2018.3']]
# osbs-client 	 [['carex', '0.29'], ['vortex', '0.29']]
# fpconst 	 [['carex', '0.7.2'], ['latex', '0.7.2'], ['silex', '0.7.2'], ['vortex', '0.7.2']]
# TwitterSearch 	 [['carex', '1.0.1'], ['latex', '1.0.1'], ['silex', '1.0.1'], ['vortex', '1.0.1']]
# bz2file 	 [['carex', '0.98'], ['latex', '0.98'], ['silex', '0.98'], ['vortex', '0.98']]
# python-ldap 	 [['carex', '2.4.17'], ['latex', '2.4.6'], ['vortex', '2.4.17']]
# wxPython 	 [['carex', '3.0.2.0'], ['latex', '2.8.12.0'], ['vortex', '3.0.2.0']]
# pyzmq 	 [['carex', '14.7.0'], ['latex', '13.0.0'], ['vortex', '14.7.0']]
# Lasagne 	 [['carex', '0.1'], ['latex', '0.2.dev1'], ['silex', '0.2.dev1'], ['vortex', '0.1']]
# PuLP 	 [['carex', '1.6.8'], ['latex', '1.6.8'], ['silex', '1.6.8'], ['vortex', '1.6.8']]
# graphviz 	 [['carex', '0.8.2'], ['latex', '0.8.2'], ['silex', '0.8.2'], ['vortex', '0.8.2']]
# cvxopt 	 [['carex', '1.1.8'], ['latex', '1.1.6'], ['vortex', '1.1.8']]
# Mako 	 [['carex', '1.0.1'], ['latex', '0.7.3'], ['vortex', '1.0.1']]
# IPy 	 [['latex', '0.75']]
# mutagen 	 [['carex', '1.29'], ['latex', '1.20'], ['vortex', '1.29']]
# certifi 	 [['carex', '2018.1.18'], ['latex', '2018.1.18'], ['silex', '2018.1.18'], ['vortex', '2018.1.18']]
# SciTools 	 [['carex', '0.9.0'], ['latex', '0.9.0'], ['silex', '0.9.0'], ['vortex', '0.9.0']]
# coverage 	 [['carex', '4.4.1'], ['latex', '4.4.1'], ['silex', '4.4.1'], ['vortex', '4.4.1']]
# pyparsing 	 [['carex', '2.2.0'], ['latex', '2.2.0'], ['silex', '2.2.0'], ['vortex', '2.2.0']]
# blivet 	 [['latex', '0.17']]
# PyWavelets 	 [['carex', '0.5.2'], ['latex', '0.5.2'], ['silex', '0.5.2'], ['vortex', '0.5.2']]
# PyYAML 	 [['carex', '3.12'], ['latex', '3.12'], ['silex', '3.12'], ['vortex', '3.12']]
# CDDB 	 [['carex', '1.4'], ['vortex', '1.4']]
# Pmw 	 [['carex', '2.0.1'], ['latex', '2.0.1'], ['silex', '2.0.1'], ['vortex', '2.0.1']]
# urlgrabber 	 [['carex', '3.10.1'], ['latex', '3.10'], ['vortex', '3.10.1']]
# psutil 	 [['carex', '3.2.1'], ['latex', '0.6.1'], ['vortex', '3.2.1']]
# py 	 [['carex', '1.4.30']]
# keyrings.alt 	 [['carex', '2.3'], ['latex', '2.3'], ['silex', '2.3'], ['vortex', '2.3']]
# pyparted 	 [['carex', '3.10.7'], ['latex', '3.9'], ['vortex', '3.10.7']]
# mpmath 	 [['carex', '1.0.0'], ['latex', '1.0.0'], ['silex', '1.0.0'], ['vortex', '1.0.0']]
# backports-abc 	 [['carex', '0.5'], ['latex', '0.5'], ['silex', '0.5'], ['vortex', '0.5']]
# fastcache 	 [['carex', '1.0.2'], ['vortex', '1.0.2']]
# wstools 	 [['carex', '0.4.5'], ['latex', '0.4.5'], ['silex', '0.4.5'], ['vortex', '0.4.5']]
# rubber 	 [['carex', '1.4'], ['latex', '1.1'], ['vortex', '1.4']]
# pandas 	 [['carex', '0.20.3'], ['latex', '0.20.3'], ['silex', '0.20.3'], ['vortex', '0.20.3']]
# scikit-image 	 [['carex', '0.13.1'], ['latex', '0.13.1'], ['silex', '0.13.1'], ['vortex', '0.13.1']]
# pymol 	 [['latex', '1.6.0.0']]
# constantly 	 [['carex', '15.1.0'], ['latex', '15.1.0'], ['silex', '15.1.0'], ['vortex', '15.1.0']]
# keyring 	 [['carex', '10.4.0'], ['latex', '10.4.0'], ['silex', '10.4.0'], ['vortex', '10.4.0']]
# meld 	 [['carex', '3.14.0'], ['vortex', '3.14.0']]
# pycparser 	 [['carex', '2.18'], ['latex', '2.18'], ['silex', '2.18'], ['vortex', '2.18']]
# pykickstart 	 [['latex', '1.99.32']]
# configobj 	 [['carex', '5.0.6'], ['latex', '5.0.6'], ['silex', '5.0.6'], ['vortex', '5.0.6']]
# pydot 	 [['carex', '1.2.3'], ['latex', '1.2.3'], ['silex', '1.2.3'], ['vortex', '1.2.3']]
# lxml 	 [['carex', '4.0.0'], ['latex', '4.1.1'], ['silex', '4.1.1'], ['vortex', '4.0.0']]
# w3lib 	 [['carex', '1.18.0'], ['latex', '1.18.0'], ['silex', '1.18.0'], ['vortex', '1.18.0']]
# Beaker 	 [['carex', '1.5.4'], ['latex', '1.5.4'], ['vortex', '1.5.4']]
# jmespath 	 [['carex', '0.9.3'], ['latex', '0.9.3'], ['silex', '0.9.3'], ['vortex', '0.9.3']]
# Automat 	 [['carex', '0.6.0'], ['latex', '0.6.0'], ['silex', '0.6.0'], ['vortex', '0.6.0']]
# compyte 	 [['carex', '0.0.1']]
# requests-oauthlib 	 [['carex', '0.8.0'], ['latex', '0.8.0'], ['silex', '0.8.0'], ['vortex', '0.8.0']]
# libasyncns 	 [['carex', '0.7'], ['latex', '0.7'], ['vortex', '0.7']]
# biopython 	 [['carex', '1.68'], ['latex', '1.60'], ['vortex', '1.68']]
# gmpy2 	 [['carex', '2.0.7'], ['vortex', '2.0.7']]
# Pyro 	 [['carex', '3.16'], ['latex', '3.16'], ['silex', '3.16'], ['vortex', '3.16']]
# requests 	 [['carex', '2.18.1'], ['latex', '2.18.4'], ['silex', '2.18.4'], ['vortex', '2.18.1']]
# scsamba.dbus 	 [['carex', '1.2.100'], ['latex', '1.2.100'], ['vortex', '1.2.100']]
# rpkg 	 [['carex', '1.46'], ['latex', '1.18'], ['vortex', '1.46']]
# arandr 	 [['carex', '0.1.9'], ['vortex', '0.1.9']]
# treetaggerwrapper 	 [['carex', '2.2.4'], ['latex', '2.2.4'], ['silex', '2.2.4'], ['vortex', '2.2.4']]
# xvfbwrapper 	 [['carex', '0.2.9'], ['latex', '0.2.9'], ['silex', '0.2.9'], ['vortex', '0.2.9']]
# logilab-common 	 [['carex', '0.63.2'], ['latex', '0.60.0'], ['vortex', '0.63.2']]
# attrs 	 [['carex', '17.2.0'], ['latex', '17.4.0'], ['silex', '17.4.0'], ['vortex', '17.2.0']]
# incremental 	 [['carex', '17.5.0'], ['latex', '17.5.0'], ['silex', '17.5.0'], ['vortex', '17.5.0']]
# SSSDConfig 	 [['carex', '1.14.2'], ['latex', '1.11.2'], ['vortex', '1.14.2']]
# di 	 [['latex', '0.3']]
# chardet 	 [['carex', '3.0.4'], ['latex', '3.0.4'], ['silex', '3.0.4'], ['vortex', '3.0.4']]
# Pygments 	 [['carex', '2.1.3'], ['latex', '1.4'], ['vortex', '2.1.3']]
# fros 	 [['latex', '1.0']]
# pytools 	 [['carex', '2015.1.2']]
# async 	 [['latex', '0.6.1']]
# Jinja2 	 [['carex', '2.9.6'], ['latex', '2.10'], ['silex', '2.10'], ['vortex', '2.9.6']]
# six 	 [['carex', '1.11.0'], ['latex', '1.11.0'], ['silex', '1.11.0'], ['vortex', '1.11.0']]
# pyPdf 	 [['carex', '1.13'], ['latex', '1.13'], ['vortex', '1.13']]
# spambayes 	 [['latex', '1.1a6']]
# liblarch 	 [['carex', '2.1.0'], ['latex', '2.1.0'], ['vortex', '2.1.0']]
# service-identity 	 [['carex', '17.0.0'], ['latex', '17.0.0'], ['silex', '17.0.0'], ['vortex', '17.0.0']]
# 4Suite-XML 	 [['carex', '1.0.2'], ['latex', '1.0.2'], ['vortex', '1.0.2']]
# cupshelpers 	 [['latex', '1.0']]
# pycuda 	 [['carex', '2016.1.2']]
# bleach 	 [['carex', '1.5.0'], ['latex', '2.1.3'], ['silex', '2.1.3'], ['vortex', '1.5.0']]
# jupyter-core 	 [['carex', '4.3.0'], ['latex', '4.3.0'], ['silex', '4.3.0'], ['vortex', '4.3.0']]
# vboxapi 	 [['carex', '1.0'], ['latex', '1.0']]
# Markdown 	 [['carex', '2.6.8'], ['latex', '2.6.9'], ['silex', '2.6.9'], ['vortex', '2.6.8']]
# Cython 	 [['carex', '0.27.1'], ['latex', '0.27.1'], ['silex', '0.27.1'], ['vortex', '0.27.1']]
# gnuplot-py 	 [['latex', '1.8'], ['silex', '1.8']]
# Pillow 	 [['carex', '5.0.0'], ['latex', '5.0.0'], ['silex', '5.0.0'], ['vortex', '5.0.0']]
# python-gnupg 	 [['carex', '0.3.8'], ['vortex', '0.3.8']]
# yum-langpacks 	 [['latex', '0.4.1']]
# distribute 	 [['latex', '0.6.36']]
# webencodings 	 [['carex', '0.5.1'], ['latex', '0.5.1'], ['silex', '0.5.1'], ['vortex', '0.5.1']]
# vobject 	 [['carex', '0.8.1rc0'], ['latex', '0.8.1rc0'], ['vortex', '0.8.1rc0']]
# backports.weakref 	 [['carex', '1.0.post1'], ['latex', '1.0.post1'], ['silex', '1.0.post1'], ['vortex', '1.0.post1']]
# oauth2client 	 [['carex', '4.1.2'], ['latex', '4.1.2'], ['silex', '4.1.2'], ['vortex', '4.1.2']]
# slip.gtk 	 [['carex', '0.6.4'], ['latex', '0.4.0'], ['vortex', '0.6.4']]
# slip 	 [['carex', '0.6.4'], ['latex', '0.4.0'], ['vortex', '0.6.4']]
# feedparser 	 [['carex', '5.2.0'], ['latex', '5.1.3'], ['vortex', '5.2.0']]
# ZSI 	 [['latex', '2.1a1']]
# Sphinx 	 [['carex', '1.2.3'], ['latex', '1.1.3'], ['vortex', '1.2.3']]
# mercurial 	 [['carex', '3.5.2'], ['latex', '2.6.3'], ['vortex', '3.5.2']]
# pygraphviz 	 [['carex', '1.3rc2'], ['vortex', '1.3rc2']]
# scservices 	 [['carex', '0.111.4'], ['latex', '0.101.10'], ['vortex', '0.111.4']]
# nltk 	 [['carex', '3.2.5'], ['latex', '3.2.5'], ['silex', '3.2.5'], ['vortex', '3.2.5']]
# galternatives 	 [['carex', '0.9'], ['latex', '0.9'], ['vortex', '0.9']]
# Django 	 [['carex', '1.8.15'], ['latex', '1.5.4'], ['vortex', '1.8.15']]
# httplib2 	 [['carex', '0.10.3'], ['latex', '0.10.3'], ['silex', '0.10.3'], ['vortex', '0.10.3']]
# fedpkg 	 [['carex', '1.25'], ['latex', '1.14'], ['vortex', '1.25']]
# google-api-python-client 	 [['carex', '1.6.4'], ['latex', '1.6.4'], ['silex', '1.6.4'], ['vortex', '1.6.4']]
# bkcharts 	 [['carex', '0.2'], ['latex', '0.2'], ['silex', '0.2'], ['vortex', '0.2']]
# pyliblzma 	 [['carex', '0.5.3'], ['latex', '0.5.3'], ['vortex', '0.5.3']]
# M2Crypto 	 [['carex', '0.22.5'], ['latex', '0.21.1'], ['vortex', '0.22.5']]
# nbxmpp 	 [['carex', '0.5.3'], ['vortex', '0.5.3']]
# subprocess32 	 [['carex', '3.2.7'], ['latex', '3.2.7'], ['silex', '3.2.7'], ['vortex', '3.2.7']]
# Tempita 	 [['carex', '0.5.1'], ['latex', '0.5.1'], ['vortex', '0.5.1']]
# xlwt 	 [['carex', '0.7.4'], ['vortex', '0.7.4']]
# botocore 	 [['carex', '1.9.16'], ['latex', '1.10.0'], ['silex', '1.10.0'], ['vortex', '1.9.16']]
# tornado 	 [['carex', '4.5.1'], ['latex', '5.0.1'], ['silex', '5.0.1'], ['vortex', '4.5.1']]
# wsgiref 	 [['latex', '0.1.2']]
# kerberos 	 [['carex', '1.1'], ['latex', '1.1'], ['vortex', '1.1']]
# Phatch 	 [['carex', '0.2.7'], ['vortex', '0.2.7']]
# SimPy 	 [['carex', '2.3.1'], ['latex', '2.3.1'], ['vortex', '2.3.1']]
# pexpect-u 	 [['latex', '2.5.1']]
# backports.ssl-match-hostname 	 [['latex', '3.4.0.2']]
# pycrypto 	 [['carex', '2.6.1'], ['latex', '2.6.1'], ['silex', '2.6.1'], ['vortex', '2.6.1']]
# simplejson 	 [['carex', '3.11.1'], ['latex', '3.11.1'], ['silex', '3.11.1'], ['vortex', '3.11.1']]
# wxPython-common 	 [['carex', '3.0.2.0'], ['latex', '2.8.12.0'], ['vortex', '3.0.2.0']]
# pycryptopp 	 [['carex', '0.6.0.1206569328141510525648634803928199668821045408958'], ['latex', '0.6.0.1206569328141510525648634803928199668821045408958'], ['vortex', '0.6.0.1206569328141510525648634803928199668821045408958']]
# sympy 	 [['carex', '1.1.1'], ['latex', '1.1.1'], ['silex', '1.1.1'], ['vortex', '1.1.1']]
# GDAL 	 [['carex', '2.0.2'], ['latex', '1.9.2'], ['vortex', '2.0.2']]
# python-bugzilla 	 [['carex', '1.2.2'], ['latex', '0.9.0'], ['vortex', '1.2.2']]
# langdetect 	 [['carex', '1.0.7'], ['latex', '1.0.7'], ['silex', '1.0.7'], ['vortex', '1.0.7']]
# scsamba 	 [['carex', '1.2.100'], ['latex', '1.2.100'], ['vortex', '1.2.100']]
# boto 	 [['carex', '2.48.0'], ['latex', '2.48.0'], ['silex', '2.48.0'], ['vortex', '2.48.0']]
# matplotlib 	 [['carex', '2.0.2'], ['latex', '2.1.2'], ['silex', '2.1.2'], ['vortex', '2.0.2']]
# Paste 	 [['carex', '1.7.5.1'], ['latex', '1.7.5.1'], ['vortex', '1.7.5.1']]
# python-dateutil 	 [['carex', '2.6.1'], ['latex', '2.7.2'], ['silex', '2.7.2'], ['vortex', '2.6.1']]
# python-debianbts 	 [['silex', '1.11']]
# pyglet 	 [['carex', '1.2.1'], ['latex', '1.2a1'], ['vortex', '1.2.1']]
# beautifulsoup4 	 [['carex', '4.3.2'], ['latex', '4.6.0'], ['silex', '4.6.0'], ['vortex', '4.3.2']]
# kitchen 	 [['carex', '1.2.1'], ['latex', '1.1.1'], ['vortex', '1.2.1']]
# futures 	 [['carex', '3.2.0'], ['latex', '3.2.0'], ['silex', '3.2.0'], ['vortex', '3.2.0']]
# pypoppler 	 [['carex', '0.12.2'], ['vortex', '0.12.2']]
# python-apt 	 [['silex', '0.9.3.10']]
# pycurl 	 [['carex', '7.19.5.1'], ['latex', '7.19.0'], ['vortex', '7.19.5.1']]
# astroid 	 [['carex', '1.3.6'], ['latex', '1.0.0'], ['vortex', '1.3.6']]
# flickrapi 	 [['carex', '1.4.2'], ['latex', '1.4.2'], ['vortex', '1.4.2']]
# ecdsa 	 [['carex', '0.11'], ['vortex', '0.11']]
# s3transfer 	 [['carex', '0.1.13'], ['latex', '0.1.13'], ['silex', '0.1.13'], ['vortex', '0.1.13']]
# Bottleneck 	 [['carex', '0.6.0'], ['vortex', '0.6.0']]
# rpm-python 	 [['carex', '4.13.0rc1'], ['vortex', '4.13.0rc1']]
# psycopg2 	 [['carex', '2.6.1'], ['latex', '2.4.5'], ['vortex', '2.6.1']]
# mistune 	 [['carex', '0.6'], ['vortex', '0.6']]
# queuelib 	 [['carex', '1.4.2'], ['latex', '1.4.2'], ['silex', '1.4.2'], ['vortex', '1.4.2']]
# ply 	 [['carex', '3.6'], ['vortex', '3.6']]
# mglob 	 [['latex', '0.4']]
# paramiko 	 [['carex', '1.15.2'], ['latex', '1.10.1'], ['vortex', '1.15.2']]
# slip.dbus 	 [['carex', '0.6.4'], ['latex', '0.4.0'], ['vortex', '0.6.4']]
# plotly 	 [['carex', '2.0.12'], ['latex', '2.1.0'], ['silex', '2.1.0'], ['vortex', '2.0.12']]
# backports.functools-lru-cache 	 [['carex', '1.5'], ['latex', '1.5'], ['silex', '1.5'], ['vortex', '1.5']]
# munch 	 [['carex', '2.0.2'], ['vortex', '2.0.2']]
# cffi 	 [['carex', '1.11.2'], ['latex', '1.11.5'], ['silex', '1.11.5'], ['vortex', '1.11.2']]
# smart-open 	 [['carex', '1.5.7'], ['latex', '1.5.7'], ['silex', '1.5.7'], ['vortex', '1.5.7']]
# initial-setup 	 [['latex', '0.3.6']]
# langtable 	 [['latex', '0.0.13']]
# xlrd 	 [['carex', '0.9.2'], ['vortex', '0.9.2']]
# egenix-mx-base 	 [['carex', '3.2.8'], ['latex', '3.2.5'], ['vortex', '3.2.8']]
# Pyrex 	 [['carex', '0.9.9'], ['latex', '0.9.9'], ['vortex', '0.9.9']]
# bunch 	 [['latex', '1.0.1']]
# offtrac 	 [['latex', '0.0.4']]
# PyX 	 [['silex', '0.12.1']]
# Unidecode 	 [['carex', '0.4.16'], ['vortex', '0.4.16']]
# zope.interface 	 [['carex', '4.4.3'], ['latex', '4.4.3'], ['silex', '4.4.3'], ['vortex', '4.4.3']]
# scipy 	 [['carex', '1.0.1'], ['latex', '1.1.0'], ['silex', '1.1.0'], ['vortex', '1.0.1']]
# hyperlink 	 [['carex', '17.3.1'], ['latex', '17.3.1'], ['silex', '17.3.1'], ['vortex', '17.3.1']]
